# %%
import requests
import csv
response = requests.get("https://gorest.co.in/public-api/users?_format=json&access-token=H4lYmIGLXZkDlpy_w0ZVS5rgcpDXbN7fhRRy")
employees = response.json()

# %%
employees
# Out:
# {'code': 200,
#  'meta': {'pagination': {'total': 2013, 'pages': 101, 'page': 1, 'limit': 20}},
#  'data': [{'id': 3202,
#    'name': 'Sajid',
#    'email': 'Sajid6@world.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 48,
#    'name': 'Daevika  Menon',
#    'email': 'daevika@stoltenberg.info',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 1745,
#    'name': 'boo',
#    'email': 'nooo12@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 2841,
#    'name': 'QIV MOM',
#    'email': 'HPC490137Q@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 2687,
#    'name': 'RIQRENY',
#    'email': 'RSSCR64NYN@gmail.com',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 2842,
#    'name': 'NY V',
#    'email': 'YFSNN8X8T0@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 1818,
#    'name': 'DY70JL5L3FSX0UBYC8AMHBGGC',
#    'email': 'FIM5EA1N4M@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 2685,
#    'name': 'O URF',
#    'email': '9RGRT6AXYD@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 3216,
#    'name': 'John Cena',
#    'email': 'johncena@8700ce.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 3198,
#    'name': 'Bangbang',
#    'email': 'Bangbang@gmail.com',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 2683,
#    'name': 'EXRNMIBSMK2HOB4P92GAFJROH',
#    'email': '29HE8Y876B@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 56,
#    'name': 'Gov. Deven Chopra',
#    'email': 'gov_chopra_deven@weber.net',
#    'gender': 'female',
#    'status': 'inactive'},
#   {'id': 2684,
#    'name': '4L52JAISRUF2FV28MUNHRV76Y',
#    'email': 'FOJOW0OOAH@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 68,
#    'name': 'Hari Kaniyar',
#    'email': 'kaniyar_hari_fr@dibbert-mann.com',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 2686,
#    'name': 'KQH4PULAT5VLVDRABK145AS4I',
#    'email': '2YWIHNTQ7C@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 61,
#    'name': 'Amritambu Mukhopadhyay CPA',
#    'email': 'amritambu_mukhopadhyay_cpa@nolan.co',
#    'gender': 'female',
#    'status': 'active'},
#   {'id': 2689,
#    'name': '856DTOKINEYQMFQY00CU9HQ8Q',
#    'email': '4JPQ5VSQSP@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 2691,
#    'name': 'F1Z7YB9EPU966VM0N4AMTJK09',
#    'email': '4PCM9GIFKM@gmail.com',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 73,
#    'name': 'sri-1395',
#    'email': 'ns@watsica-strosin.net',
#    'gender': 'male',
#    'status': 'active'},
#   {'id': 72,
#    'name': 'Bhishma Varman',
#    'email': 'bhishma_varman@bednar.name',
#    'gender': 'male',
#    'status': 'active'}]}

# %%
employees['data']
# Out:
# [{'id': 3202,
#   'name': 'Sajid',
#   'email': 'Sajid6@world.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 48,
#   'name': 'Daevika  Menon',
#   'email': 'daevika@stoltenberg.info',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 1745,
#   'name': 'boo',
#   'email': 'nooo12@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 2841,
#   'name': 'QIV MOM',
#   'email': 'HPC490137Q@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 2687,
#   'name': 'RIQRENY',
#   'email': 'RSSCR64NYN@gmail.com',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 2842,
#   'name': 'NY V',
#   'email': 'YFSNN8X8T0@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 1818,
#   'name': 'DY70JL5L3FSX0UBYC8AMHBGGC',
#   'email': 'FIM5EA1N4M@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 2685,
#   'name': 'O URF',
#   'email': '9RGRT6AXYD@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 3216,
#   'name': 'John Cena',
#   'email': 'johncena@8700ce.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 3198,
#   'name': 'Bangbang',
#   'email': 'Bangbang@gmail.com',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 2683,
#   'name': 'EXRNMIBSMK2HOB4P92GAFJROH',
#   'email': '29HE8Y876B@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 56,
#   'name': 'Gov. Deven Chopra',
#   'email': 'gov_chopra_deven@weber.net',
#   'gender': 'female',
#   'status': 'inactive'},
#  {'id': 2684,
#   'name': '4L52JAISRUF2FV28MUNHRV76Y',
#   'email': 'FOJOW0OOAH@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 68,
#   'name': 'Hari Kaniyar',
#   'email': 'kaniyar_hari_fr@dibbert-mann.com',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 2686,
#   'name': 'KQH4PULAT5VLVDRABK145AS4I',
#   'email': '2YWIHNTQ7C@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 61,
#   'name': 'Amritambu Mukhopadhyay CPA',
#   'email': 'amritambu_mukhopadhyay_cpa@nolan.co',
#   'gender': 'female',
#   'status': 'active'},
#  {'id': 2689,
#   'name': '856DTOKINEYQMFQY00CU9HQ8Q',
#   'email': '4JPQ5VSQSP@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 2691,
#   'name': 'F1Z7YB9EPU966VM0N4AMTJK09',
#   'email': '4PCM9GIFKM@gmail.com',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 73,
#   'name': 'sri-1395',
#   'email': 'ns@watsica-strosin.net',
#   'gender': 'male',
#   'status': 'active'},
#  {'id': 72,
#   'name': 'Bhishma Varman',
#   'email': 'bhishma_varman@bednar.name',
#   'gender': 'male',
#   'status': 'active'}]

# %%
import csv 

with open('employees.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['name', 'gender', 'email', 'is_active'])
    writer.writeheader()
    for employee in employees['data']:
        name = employee['name']
        email = employee['email']
        gender = employee['gender']
        is_active = 1 if employee['status'] == 'active' else 0
        writer.writerow({'name': name, 'gender': gender, 'email': email, 'is_active': is_active})

# %%
import pandas as pd

data = pd.read_csv('employees.csv')
data
# Out:
#                        name  gender  \
# 0      Msgr. Shanti Mahajan  female
# 1         Fr. Daksha Achari  female
# 2            Chandak Tagore  female
# 3                Tarun Naik  female
# 4       Jyotis Bhattacharya    male
# 5       Amb. Rajinder Ahuja    male
# 6                 Tanya Jha  female
# 7           Swarnalata Rana    male
# 8           Kashyapi Tagore  female
# 9   Sen. Amarnath Bharadwaj  female
# 10               Suma Mehra    male
# 11           Gotum Banerjee    male
# 12             Baidehi Kaur  female
# 13           Gautam Dubashi  female
# 14                     5164    male
# 15         Allasani Peddana  female
# 16           Abhi Begowalia    male
# 17                 Patricia  female
# 18          Harit Nair Vfff  female
# 19            Sakura Haruno  female
#
#                                           email  is_active
# 0   msgr_shanti_mahajan@wintheiser-friesen.info          1
# 1             fr_daksha_achari@ullrich-kulas.io          1
# 2              chandak_tagore@weimann-white.net          0
# 3                naik_tarun@bahringer-mayer.org          1
# 4             bhattacharya_jyotis@schinner.info          0
# 5                ahuja_rajinder_amb@luettgen.io          1
# 6                          jha_tanya@frami.name          0
# 7                swarnalata_rana@zieme-nader.io          1
# 8                  tagore_kashyapi@jacobson.org          1
# 9             amarnath_sen_bharadwaj@becker.org          0
# 10                        mehra_suma@blick.info          1
# 11                    banerjee_gotum@kuhlman.io          0
# 12                     baidehi_kaur@krajcik.org          0
# 13                  dubashi_gautam@hermiston.io          1
# 14               abbott_ajit_amb@funk-lesch.net          1
# 15                     allasanipeddana@15ce.com          1
# 16                             abhi@yopmail.com          1
# 17                       patricia1234@gmail.com          1
# 18                  nair_harit_v@miller-lowe.io          0
# 19                      nayar_shubha@ledner.com          1
